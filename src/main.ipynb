V006.npy', '../data/features/L04_V007.npy', '../data/features/L04_V008.npy', '../data/features/L04_V009.npy', '../data/features/L04_V010.npy', '../data/features/L04_V011.npy', '../data/features/L04_V012.npy', '../data/features/L04_V013.npy', '../data/features/L04_V014.npy', '../data/features/L04_V015.npy', '../data/features/L04_V016.npy', '../data/features/L04_V017.npy', '../data/features/L04_V018.npy', '../data/features/L04_V019.npy', '../data/features/L04_V020.npy', '../data/features/L04_V021.npy', '../data/features/L04_V022.npy', '../data/features/L04_V023.npy', '../data/features/L04_V024.npy', '../data/features/L04_V025.npy', '../data/features/L04_V026.npy', '../data/features/L04_V027.npy', '../data/features/L04_V028.npy', '../data/features/L04_V029.npy', '../da ...
# Loading FrameDocs: 100%|#####################################################################################################################################################################################| 737/737 [00:43<00:00, 16.86it/s]
# Done...
# Index root database...
# 8 threads had found...
# Done
# Loading model: Done!

# %% [markdown]
# ## DEMO

# %% [markdown]
# ### Query

# %% [markdown]
# ### Filter 1

# %%
results1 = model.search_and_visualize(
    query_text="Video of two men pointing at paintings on the wall. Among the paintings, there is a drawing of Uncle Ho on a red background in the middle of the remaining paintings. On another wall there are hanging frames like certificates of merit.",
    audio_texts=[],
    topk=200,
)  
# results1.contains(keywords=[]).visualize()
# Out:
#
#         <style>
#             .image-list {
#                 display: grid;
#                 grid-template-columns: repeat(2, 1fr);
#                 grid-gap: 10px;
#                 max-height: 900px;
#                 overflow-y: scroll;
#             }
#
#             .image-item {
#                 position: relative;
#             }
#
#             .image-item img {
#                 max-width: 100%;
#                 height: auto;
#                 cursor: pointer;
#             }
#
#             .image-item a {
#                 display: none;
#                 position: absolute;
#                 top: 0;
#                 left: 0;
#                 width: 100%;
#                 height: 100%;
#                 background-color: rgba(0, 0, 0, 0.7);
#                 text-align: center;
#                 justify-content: center;
#                 align-items: center;
#                 text-decoration: none;
#                 color: white;
#             }
#
#             .image-item:hover a {
#                 display: flex;
#             }
#         </style>
#
#        <div class="image-list">
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L06_V027/0119.jpg" alt="Ảnh 1">
#                 <figcaption>L06_V027 - 11567 - 7'42.7</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/j_wih58xgf8 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L15_V023/0065.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V023 - 7079 - 4'43.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/wwmiQueBqPQ target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L14_V006/0191.jpg" alt="Ảnh 1">
#                 <figcaption>L14_V006 - 20522 - 13'40.9</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/3a7NpTAsE1Q target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L15_V022/0106.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V022 - 9330 - 6'13.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/ZsDW3HnZ6os target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L15_V022/0007.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V022 - 494 - 0'19.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/ZsDW3HnZ6os target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L15_V024/0092.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V024 - 9833 - 6'33.3</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/8bZTmqbyN28 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L06_V018/0144.jpg" alt="Ảnh 1">
#                 <figcaption>L06_V018 - 16734 - 11'9.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/UzD9V--cfgY target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L06_V003/0174.jpg" alt="Ảnh 1">
#                 <figcaption>L06_V003 - 19052 - 12'42.1</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/CEH_ZEoKJ_A target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L15_V022/0103.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V022 - 8942 - 5'57.7</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/ZsDW3HnZ6os target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L14_V011/0162.jpg" alt="Ảnh 1">
#                 <figcaption>L14_V011 - 17813 - 11'52.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/eNrJsxpv960 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L10_V017/0118.jpg" alt="Ảnh 1">
#                 <figcaption>L10_V017 - 11835 - 7'53.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/2B5qTBE8pB0 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L12_V008/0136.jpg" alt="Ảnh 1">
#                 <figcaption>L12_V008 - 14596 - 9'43.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/zaMom_a6PnM target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L07_V018/0255.jpg" alt="Ảnh 1">
#                 <figcaption>L07_V018 - 27420 - 18'16.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/pR52v86ZGW4 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L14_V007/0193.jpg" alt="Ảnh 1">
#                 <figcaption>L14_V007 - 19419 - 12'56.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/XUMxGW0Ppd0 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L15_V022/0104.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V022 - 9098 - 6'3.9</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/ZsDW3HnZ6os target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L12_V023/0127.jpg" alt="Ảnh 1">
#                 <figcaption>L12_V023 - 13208 - 8'48.3</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/j7jOTXrQi68 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L05_V017/0194.jpg" alt="Ảnh 1">
#                 <figcaption>L05_V017 - 22683 - 15'7.3</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/NhcHMAmLmWw target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L15_V016/0272.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V016 - 28201 - 18'48.0</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/7EWNRXuO2DA target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L14_V007/0185.jpg" alt="Ảnh 1">
#                 <figcaption>L14_V007 - 18335 - 12'13.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/XUMxGW0Ppd0 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L10_V017/0107.jpg" alt="Ảnh 1">
#                 <figcaption>L10_V017 - 10890 - 7'15.6</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/2B5qTBE8pB0 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../WebApp/server/keyframes/L05_V010/0354.jpg" alt="Ảnh 1">

# %%
print(results1.to_json())
# Out:
# [{'video': 'L06_V027', 'frame': 11567}, {'video': 'L15_V023', 'frame': 7079}, {'video': 'L14_V006', 'frame': 20522}, {'video': 'L15_V022', 'frame': 9330}, {'video': 'L15_V022', 'frame': 494}, {'video': 'L15_V024', 'frame': 9833}, {'video': 'L06_V018', 'frame': 16734}, {'video': 'L06_V003', 'frame': 19052}, {'video': 'L15_V022', 'frame': 8942}, {'video': 'L14_V011', 'frame': 17813}, {'video': 'L10_V017', 'frame': 11835}, {'video': 'L12_V008', 'frame': 14596}, {'video': 'L07_V018', 'frame': 27420}, {'video': 'L14_V007', 'frame': 19419}, {'video': 'L15_V022', 'frame': 9098}, {'video': 'L12_V023', 'frame': 13208}, {'video': 'L05_V017', 'frame': 22683}, {'video': 'L15_V016', 'frame': 28201}, {'video': 'L14_V007', 'frame': 18335}, {'video': 'L10_V017', 'frame': 10890}, {'video': 'L05_V010', 'frame': 25296}, {'video': 'L04_V004', 'frame': 17727}, {'video': 'L05_V022', 'frame': 23554}, {'video': 'L08_V001', 'frame': 9810}, {'video': 'L07_V026', 'frame': 21221}, {'video': 'L08_V006', 'frame': 15637}, {'video': 'L14_V023', 'frame': 19740}, {'video': 'L06_V018', 'frame': 17541}, {'video': 'L11_V019', 'frame': 6684}, {'video': 'L06_V003', 'frame': 19868}, {'video': 'L10_V017', 'frame': 11065}, {'video': 'L06_V018', 'frame': 16436}, {'video': 'L06_V027', 'frame': 11470}, {'video': 'L10_V017', 'frame': 10448}, {'video': 'L07_V030', 'frame': 21852}, {'video': 'L13_V024', 'frame': 27145}, {'video': 'L07_V030', 'frame': 21996}, {'video': 'L14_V022', 'frame': 21671}, {'video': 'L10_V017', 'frame': 11352}, {'video': 'L15_V022', 'frame': 8820}, {'video': 'L07_V024', 'frame': 5990}, {'video': 'L05_V018', 'frame': 22522}, {'video': 'L03_V025', 'frame': 6360}, {'video': 'L12_V014', 'frame': 18175}, {'video': 'L10_V016', 'frame': 4220}, {'video': 'L13_V002', 'frame': 28157}, {'video': 'L06_V018', 'frame': 16194}, {'video': 'L12_V001', 'frame': 20546}, {'video': 'L20_V093', 'frame': 20335}, {'video': 'L06_V027', 'frame': 11389}, {'video': 'L19_V013', 'frame': 16422}, {'video': 'L10_V017', 'frame': 11579}, {'video': 'L03_V005', 'frame': 26187}, {'video': 'L07_V030', 'frame': 21765}, {'video': 'L11_V031', 'frame': 9455}, {'video': 'L10_V011', 'frame': 20815}, {'video': 'L14_V022', 'frame': 21036}, {'video': 'L14_V009', 'frame': 15960}, {'video': 'L15_V023', 'frame': 8433}, {'video': 'L05_V017', 'frame': 22364}, {'video': 'L13_V024', 'frame': 26618}, {'video': 'L15_V024', 'frame': 9524}, {'video': 'L07_V024', 'frame': 5927}, {'video': 'L10_V024', 'frame': 9691}, {'video': 'L12_V014', 'frame': 17883}, {'video': 'L14_V022', 'frame': 21083}, {'video': 'L10_V002', 'frame': 15597}, {'video': 'L04_V020', 'frame': 20584}, {'video': 'L15_V024', 'frame': 10733}, {'video': 'L15_V016', 'frame': 28439}, {'video': 'L08_V006', 'frame': 15515}, {'video': 'L10_V017', 'frame': 10852}, {'video': 'L03_V024', 'frame': 28302}, {'video': 'L03_V025', 'frame': 6313}, {'video': 'L10_V017', 'frame': 11693}, {'video': 'L15_V014', 'frame': 22818}, {'video': 'L11_V028', 'frame': 20900}, {'video': 'L07_V030', 'frame': 20897}, {'video': 'L08_V021', 'frame': 15699}, {'video': 'L07_V009', 'frame': 23207}, {'video': 'L11_V020', 'frame': 29400}, {'video': 'L14_V025', 'frame': 6634}, {'video': 'L03_V024', 'frame': 28475}, {'video': 'L02_V016', 'frame': 16307}, {'video': 'L06_V027', 'frame': 11160}, {'video': 'L12_V008', 'frame': 14694}, {'video': 'L06_V027', 'frame': 11645}, {'video': 'L12_V008', 'frame': 15319}, {'video': 'L13_V027', 'frame': 20145}, {'video': 'L05_V017', 'frame': 22802}, {'video': 'L19_V055', 'frame': 1024}, {'video': 'L15_V024', 'frame': 9267}, {'video': 'L07_V020', 'frame': 21738}, {'video': 'L19_V023', 'frame': 16262}, {'video': 'L01_V001', 'frame': 22332}, {'video': 'L06_V003', 'frame': 18776}, {'video': 'L03_V025', 'frame': 5460}, {'video': 'L16_V020', 'frame': 8037}, {'video': 'L11_V002', 'frame': 1451}, {'video': 'L11_V028', 'frame': 26152}, {'video': 'L15_V024', 'frame': 9690}, {'video': 'L10_V011', 'frame': 20125}, {'video': 'L12_V014', 'frame': 11127}, {'video' ...

# %%
results1 = model.search_in_sequence_and_visualize(
    query_text_1="device on green surface",
    query_text_2="a mobile phone on hands",
    audio_texts=[],
    topk=200,
)
