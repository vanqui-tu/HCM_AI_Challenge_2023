# %% [markdown]
# ## Import modules

# %%
from aic23_model import model
# Out:
# Loading model...
# Loading Frame Doc: 100%|##########| 737/737 [00:16<00:00, 46.01it/s]
# Done...
# Index root database...
# 12 threads had found...
# Done
# Loading model: Done!

# %% [markdown]
# ## DEMO

# %% [markdown]
# ### Query

# %% [markdown]
# ### Filter 1

# %%
results1 = model.search_and_visualize(
    query_text="the bird land on the man's hand.",
    audio_texts=[],
    topk=1000,
)  
results1.contains(keywords=[]).visualize()
# Out:
#
#         <style>
#             .image-list {
#                 display: grid;
#                 grid-template-columns: repeat(2, 1fr);
#                 grid-gap: 10px;
#                 max-height: 900px;
#                 overflow-y: scroll;
#             }
#
#             .image-item {
#                 position: relative;
#             }
#
#             .image-item img {
#                 max-width: 100%;
#                 height: auto;
#                 cursor: pointer;
#             }
#
#             .image-item a {
#                 display: none;
#                 position: absolute;
#                 top: 0;
#                 left: 0;
#                 width: 100%;
#                 height: 100%;
#                 background-color: rgba(0, 0, 0, 0.7);
#                 text-align: center;
#                 justify-content: center;
#                 align-items: center;
#                 text-decoration: none;
#                 color: white;
#             }
#
#             .image-item:hover a {
#                 display: flex;
#             }
#         </style>
#
#        <div class="image-list">
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L10_V009\0161.jpg" alt="Ảnh 1">
#                 <figcaption>L10_V009 - 16614 - 11'4.6</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/PTpmWj9qk0Y target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L09_V002\0238.jpg" alt="Ảnh 1">
#                 <figcaption>L09_V002 - 26127 - 17'25.1</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/2vzVM4ArcUI target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L15_V010\0238.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V010 - 26612 - 17'44.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/XeuwUybJuzg target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L20_V081\0203.jpg" alt="Ảnh 1">
#                 <figcaption>L20_V081 - 20490 - 13'39.6</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/5otiHJV2CBg target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L09_V002\0239.jpg" alt="Ảnh 1">
#                 <figcaption>L09_V002 - 26172 - 17'26.9</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/2vzVM4ArcUI target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L03_V019\0337.jpg" alt="Ảnh 1">
#                 <figcaption>L03_V019 - 24676 - 16'27.0</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/v1YyJHJaZ3c target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L14_V020\0164.jpg" alt="Ảnh 1">
#                 <figcaption>L14_V020 - 16755 - 11'10.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/iEgzr15zrtI target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L19_V038\0184.jpg" alt="Ảnh 1">
#                 <figcaption>L19_V038 - 20665 - 11'29.6</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/Lip7kpzubmY target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L11_V028\0259.jpg" alt="Ảnh 1">
#                 <figcaption>L11_V028 - 26888 - 17'55.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/vzdla60LK5g target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L11_V017\0215.jpg" alt="Ảnh 1">
#                 <figcaption>L11_V017 - 22467 - 14'58.7</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/XKkiJoOr8Rs target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L11_V005\0148.jpg" alt="Ảnh 1">
#                 <figcaption>L11_V005 - 14281 - 9'31.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/XTL7SgO0p68 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L11_V029\0264.jpg" alt="Ảnh 1">
#                 <figcaption>L11_V029 - 28987 - 19'19.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/ShTKrEhJd_k target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L03_V028\0122.jpg" alt="Ảnh 1">
#                 <figcaption>L03_V028 - 11733 - 7'49.3</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/tq5SGXQ2s2Y target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L05_V015\0189.jpg" alt="Ảnh 1">
#                 <figcaption>L05_V015 - 19762 - 13'10.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/HF9_EaDdkwU target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L03_V017\0297.jpg" alt="Ảnh 1">
#                 <figcaption>L03_V017 - 28555 - 19'2.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/ifOnmSvnFzA target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L05_V026\0115.jpg" alt="Ảnh 1">
#                 <figcaption>L05_V026 - 12511 - 8'20.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/7UPven2EDC8 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L17_V022\0113.jpg" alt="Ảnh 1">
#                 <figcaption>L17_V022 - 4118 - 2'44.7</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/xnSqCkq6SpA target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L11_V002\0102.jpg" alt="Ảnh 1">
#                 <figcaption>L11_V002 - 9444 - 6'17.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/TkC0hUM0A5U target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L08_V025\0232.jpg" alt="Ảnh 1">
#                 <figcaption>L08_V025 - 25861 - 17'14.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/Z7_zIwYP9v4 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L03_V028\0284.jpg" alt="Ảnh 1">
#                 <figcaption>L03_V028 - 28170 - 18'46.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/tq5SGXQ2s2Y target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L07_V019\0092.jpg" alt="Ảnh 1">
#                 <figcaption>L07_V019 - 9720 - 6'28.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/TazdiV-r1JQ target="_blank">Xem chi t
#
#         <style>
#             .image-list {
#                 display: grid;
#                 grid-template-columns: repeat(2, 1fr);
#                 grid-gap: 10px;
#                 max-height: 900px;
#                 overflow-y: scroll;
#             }
#
#             .image-item {
#                 position: relative;
#             }
#
#             .image-item img {
#                 max-width: 100%;
#                 height: auto;
#                 cursor: pointer;
#             }
#
#             .image-item a {
#                 display: none;
#                 position: absolute;
#                 top: 0;
#                 left: 0;
#                 width: 100%;
#                 height: 100%;
#                 background-color: rgba(0, 0, 0, 0.7);
#                 text-align: center;
#                 justify-content: center;
#                 align-items: center;
#                 text-decoration: none;
#                 color: white;
#             }
#
#             .image-item:hover a {
#                 display: flex;
#             }
#         </style>
#
#        <div class="image-list">
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L10_V009\0161.jpg" alt="Ảnh 1">
#                 <figcaption>L10_V009 - 16614 - 11'4.6</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/PTpmWj9qk0Y target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L09_V002\0238.jpg" alt="Ảnh 1">
#                 <figcaption>L09_V002 - 26127 - 17'25.1</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/2vzVM4ArcUI target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L15_V010\0238.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V010 - 26612 - 17'44.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/XeuwUybJuzg target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L20_V081\0203.jpg" alt="Ảnh 1">
#                 <figcaption>L20_V081 - 20490 - 13'39.6</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/5otiHJV2CBg target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L09_V002\0239.jpg" alt="Ảnh 1">
#                 <figcaption>L09_V002 - 26172 - 17'26.9</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/2vzVM4ArcUI target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L03_V019\0337.jpg" alt="Ảnh 1">
#                 <figcaption>L03_V019 - 24676 - 16'27.0</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/v1YyJHJaZ3c target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L14_V020\0164.jpg" alt="Ảnh 1">
#                 <figcaption>L14_V020 - 16755 - 11'10.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/iEgzr15zrtI target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L19_V038\0184.jpg" alt="Ảnh 1">
#                 <figcaption>L19_V038 - 20665 - 11'29.6</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/Lip7kpzubmY target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L11_V028\0259.jpg" alt="Ảnh 1">
#                 <figcaption>L11_V028 - 26888 - 17'55.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/vzdla60LK5g target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L11_V017\0215.jpg" alt="Ảnh 1">
#                 <figcaption>L11_V017 - 22467 - 14'58.7</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/XKkiJoOr8Rs target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L11_V005\0148.jpg" alt="Ảnh 1">
#                 <figcaption>L11_V005 - 14281 - 9'31.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/XTL7SgO0p68 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L11_V029\0264.jpg" alt="Ảnh 1">
#                 <figcaption>L11_V029 - 28987 - 19'19.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/ShTKrEhJd_k target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L03_V028\0122.jpg" alt="Ảnh 1">
#                 <figcaption>L03_V028 - 11733 - 7'49.3</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/tq5SGXQ2s2Y target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L05_V015\0189.jpg" alt="Ảnh 1">
#                 <figcaption>L05_V015 - 19762 - 13'10.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/HF9_EaDdkwU target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L03_V017\0297.jpg" alt="Ảnh 1">
#                 <figcaption>L03_V017 - 28555 - 19'2.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/ifOnmSvnFzA target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L05_V026\0115.jpg" alt="Ảnh 1">
#                 <figcaption>L05_V026 - 12511 - 8'20.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/7UPven2EDC8 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L17_V022\0113.jpg" alt="Ảnh 1">
#                 <figcaption>L17_V022 - 4118 - 2'44.7</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/xnSqCkq6SpA target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L11_V002\0102.jpg" alt="Ảnh 1">
#                 <figcaption>L11_V002 - 9444 - 6'17.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/TkC0hUM0A5U target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L08_V025\0232.jpg" alt="Ảnh 1">
#                 <figcaption>L08_V025 - 25861 - 17'14.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/Z7_zIwYP9v4 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L03_V028\0284.jpg" alt="Ảnh 1">
#                 <figcaption>L03_V028 - 28170 - 18'46.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/tq5SGXQ2s2Y target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L07_V019\0092.jpg" alt="Ảnh 1">
#                 <figcaption>L07_V019 - 9720 - 6'28.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/TazdiV-r1JQ target="_blank">Xem chi t
